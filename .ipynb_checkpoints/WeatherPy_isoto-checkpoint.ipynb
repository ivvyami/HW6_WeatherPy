# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys_isoto import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
# We need Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}units={units}&appid={api_key}&q="

# %%
print(query_url)
#country
#dt
#clouds
#speed
#temp_max
#humidity
#lat
#lon
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=8c075813bfc9022369cf725c0e32018d&q=

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#set up lists to hold info
Cities = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

#loop through the list of cities and perform a request for dat on each
print("Beginning Data Retreival")
print("----------------------------")
for city in cities:
    try: 
        print(f"Processing Record | {city}")
        response = requests.get(query_url + city).json()
        Cities.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["sys"]["sunset"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
    except (KeyError):
        print("City not found. Skipping...")
    print("----------------------------")
# Out:
# Beginning Data Retreival
# ----------------------------
# Processing Record | katsuura
# ----------------------------
# Processing Record | bima
# ----------------------------
# Processing Record | meyungs
# City not found. Skipping...
# ----------------------------
# Processing Record | moctezuma
# ----------------------------
# Processing Record | puerto ayora
# ----------------------------
# Processing Record | lebu
# ----------------------------
# Processing Record | pacific grove
# ----------------------------
# Processing Record | namie
# ----------------------------
# Processing Record | ushuaia
# ----------------------------
# Processing Record | punta arenas
# ----------------------------
# Processing Record | hobart
# ----------------------------
# Processing Record | madimba
# ----------------------------
# Processing Record | fildu de jos
# ----------------------------
# Processing Record | tumannyy
# City not found. Skipping...
# ----------------------------
# Processing Record | rikitea
# ----------------------------
# Processing Record | hilo
# ----------------------------
# Processing Record | gat
# ----------------------------
# Processing Record | ayer itam
# City not found. Skipping...
# ----------------------------
# Processing Record | port blair
# ----------------------------
# Processing Record | albany
# ----------------------------
# Processing Record | victoria
# ----------------------------
# Processing Record | tawkar
# City not found. Skipping...
# ----------------------------
# Processing Record | kavieng
# ----------------------------
# Processing Record | mataura
# ----------------------------
# Processing Record | ancud
# ----------------------------
# Processing Record | yellowknife
# ----------------------------
# Processing Record | palabuhanratu
# City not found. Skipping...
# ----------------------------
# Processing Record | busselton
# ----------------------------
# Processing Record | port elizabeth
# ----------------------------
# Processing Record | kapaa
# ----------------------------
# Processing Record | new waterford
# ----------------------------
# Processing Record | kokstad
# ----------------------------
# Processing Record | palmeira
# ----------------------------
# Processing Record | tuktoyaktuk
# ----------------------------
# Processing Record | bluff
# ----------------------------
# Processing Record | havoysund
# ----------------------------
# Processing Record | magadi
# ----------------------------
# Processing Record | cape town
# ----------------------------
# Processing Record | tasiilaq
# ----------------------------
# Processing Record | fairbanks
# ----------------------------
# Processing Record | carhuamayo
# ----------------------------
# Processing Record | coahuayana
# ----------------------------
# Processing Record | hithadhoo
# ----------------------------
# Processing Record | neiafu
# ----------------------------
# Processing Record | lola
# ----------------------------
# Processing Record | clyde river
# ----------------------------
# Processing Record | serenje
# ----------------------------
# Processing Record | bowen
# ----------------------------
# Processing Record | beringovskiy
# ----------------------------
# Processing Record | butaritari
# ----------------------------
# Processing Record | saint anthony
# ----------------------------
# Processing Record | bethel
# ----------------------------
# Processing Record | martapura
# ----------------------------
# Processing Record | guaratinga
# City not found. Skipping...
# ----------------------------
# Processing Record | salalah
# ----------------------------
# Processing Record | acapulco
# ----------------------------
# Processing Record | taolanaro
# City not found. Skipping...
# ----------------------------
# Processing Record | khatanga
# ----------------------------
# Processing Record | arraial do cabo
# ----------------------------
# Processing Record | saint george
# ----------------------------
# Processing Record | chokurdakh
# ----------------------------
# Processing Record | santa cruz
# ----------------------------
# Processing Record | birao
# ----------------------------
# Processing Record | illoqqortoormiut
# City not found. Skipping...
# ----------------------------
# Processing Record | dongsheng
# ----------------------------
# Processing Record | sinnamary
# ----------------------------
# Processing Record | kanniyakumari
# ----------------------------
# Processing Record | kodiak
# ----------------------------
# Processing Record | severo-kurilsk
# ----------------------------
# Processing Record | luderitz
# ----------------------------
# Processing Record | dongning
# ----------------------------
# Processing Record | samusu
# City not found. Skipping...
# ----------------------------
# Processing Record | attawapiskat
# City not found. Skipping...
# ----------------------------
# Processing Record | nikolskoye
# ----------------------------
# Processing Record | huaicheng
# ----------------------------
# Processing Record | nishihara
# ----------------------------
# Processing Record | inhambane
# ----------------------------
# Processing Record | matadi
# ----------------------------
# Processing Record | nyurba
# ----------------------------
# Processing Record | upernavik
# ----------------------------
# Processing Record | hong gai
# ----------------------------
# Processing Record | barrow
# ----------------------------
# Processing Record | lhokseumawe
# ----------------------------
# Processing Record | avarua
# ----------------------------
# Processing Record | vaini
# ----------------------------
# Processing Record | kahului
# ----------------------------
# Processing Record | torbay
# ----------------------------
# Processing Record | panjab
# ----------------------------
# Processing Record | jamestown
# ----------------------------
# Processing Record | hermanus
# ----------------------------
# Processing Record | zhezkazgan
# ----------------------------
# Processing Record | qaanaaq
# ----------------------------
# Processing Record | gualeguaychu
# ----------------------------
# Processing Record | san patricio
# ----------------------------
# Processing Record | barentsburg
# City not found. Skipping...
# ----------------------------
# Processing Record | dikson
# ----------------------------
# Processing Record | georgetown
# ----------------------------
# Processing Record | sharan
# ----------------------------
# Processing Record | guerrero negro
# ----------------------------
# Processing Record | magna
# ----------------------------
# Processing Record | ilulissat
# ----------------------------
# Processing Record | new norfolk
# ----------------------------
# Processing Record | gamboula
# ----------------------------
# Processing Record | hamilton
# ----------------------------
# Processing Record | marystown
# ----------------------------
# Processing Record | bengkulu
# City not found. Skipping...
# ----------------------------
# Processing Record | singaraja
# ----------------------------
# Processing Record | ponta do sol
# ----------------------------
# Processing Record | lata
# ----------------------------
# Processing Record | port alfred
# ----------------------------
# Processing Record | one hundred mile house
# City not found. Skipping...
# ----------------------------
# Processing Record | lolua
# City not found. Skipping...
# ----------------------------
# Processing Record | atbasar
# ----------------------------
# Processing Record | mayo
# ----------------------------
# Processing Record | omsukchan
# ----------------------------
# Processing Record | redlands
# ----------------------------
# Processing Record | san fernando
# ----------------------------
# Processing Record | marsa matruh
# ----------------------------
# Processing Record | vila velha
# ----------------------------
# Processing Record | beitbridge
# ----------------------------
# Processing Record | mys shmidta
# City not found. Skipping...
# ----------------------------
# Processing Record | marrakesh
# ----------------------------
# Processing Record | belushya guba
# City not found. Skipping...
# ----------------------------
# Processing Record | amderma
# City not found. Skipping...
# ----------------------------
# Processing Record | avera
# ----------------------------
# Processing Record | doctor pedro p. pena
# City not found. Skipping...
# ----------------------------
# Processing Record | nizhniy baskunchak
# ----------------------------
# Processing Record | san andres
# ----------------------------
# Processing Record | loreto
# ----------------------------
# Processing Record | golubitskaya
# ----------------------------
# Processing Record | scandiano
# ----------------------------
# Processing Record | nizhneyansk
# City not found. Skipping...
# ----------------------------
# Processing Record | cidreira
# ----------------------------
# Processing Record | bambanglipuro
# ----------------------------
# Processing Record | faanui
# ----------------------------
# Processing Record | pucallpa
# ----------------------------
# Processing Record | touros
# ----------------------------
# Processing Record | conceicao da barra
# ----------------------------
# Processing Record | ambon
# ----------------------------
# Processing Record | kiama
# ----------------------------
# Processing Record | norman wells
# ----------------------------
# Processing Record | abu zabad
# ----------------------------
# Processing Record | da nang
# City not found. Skipping...
# ----------------------------
# Processing Record | toliary
# City not found. Skipping...
# ----------------------------
# Processing Record | tuatapere
# ----------------------------
# Processing Record | adrar
# ----------------------------
# Processing Record | kudahuvadhoo
# ----------------------------
# Processing Record | atuona
# ----------------------------
# Processing Record | kruisfontein
# ----------------------------
# Processing Record | hofn
# ----------------------------
# Processing Record | pitimbu
# ----------------------------
# Processing Record | bathsheba
# ----------------------------
# Processing Record | rodeo
# ----------------------------
# Processing Record | castro
# ----------------------------
# Processing Record | waipawa
# ----------------------------
# Processing Record | vostok
# ----------------------------
# Processing Record | kota
# ----------------------------
# Processing Record | bredasdorp
# ----------------------------
# Processing Record | nara
# ----------------------------
# Processing Record | hun
# ----------------------------
# Processing Record | chemax
# ----------------------------
# Processing Record | namibe
# ----------------------------
# Processing Record | kysyl-syr
# ----------------------------
# Processing Record | praia da vitoria
# ----------------------------
# Processing Record | mehamn
# ----------------------------
# Processing Record | longyearbyen
# ----------------------------
# Processing Record | freeport
# ----------------------------
# Processing Record | bilibino
# ----------------------------
# Processing Record | fangshan
# ----------------------------
# Processing Record | waverley
# ----------------------------
# Processing Record | maloy
# ----------------------------
# Processing Record | alamos
# ----------------------------
# Processing Record | mokhsogollokh
# ----------------------------
# Processing Record | thompson
# ----------------------------
# Processing Record | caxito
# ----------------------------
# Processing Record | plymouth
# ----------------------------
# Processing Record | saskylakh
# ----------------------------
# Processing Record | kamenka
# ----------------------------
# Processing Record | husavik
# ----------------------------
# Processing Record | tsihombe
# City not found. Skipping...
# ----------------------------
# Processing Record | esperance
# ----------------------------
# Processing Record | lorengau
# ----------------------------
# Processing Record | fort-shevchenko
# ----------------------------
# Processing Record | havelock
# ----------------------------
# Processing Record | lumeje
# ----------------------------
# Processing Record | hualmay
# ----------------------------
# Processing Record | grindavik
# ----------------------------
# Processing Record | carnarvon
# ----------------------------
# Processing Record | pocinhos
# ----------------------------
# Processing Record | padang
# ----------------------------
# Processing Record | qaqortoq
# ----------------------------
# Processing Record | pangnirtung
# ----------------------------
# Processing Record | beloha
# ----------------------------
# Processing Record | khandyga
# ----------------------------
# Processing Record | lakeside
# ----------------------------
# Processing Record | phan rang
# City not found. Skipping...
# ----------------------------
# Processing Record | fushan
# ----------------------------
# Processing Record | lavrentiya
# ----------------------------
# Processing Record | baruun-urt
# ----------------------------
# Processing Record | tynda
# ----------------------------
# Processing Record | samarai
# ----------------------------
# Processing Record | post falls
# ----------------------------
# Processing Record | bongandanga
# ----------------------------
# Processing Record | jadu
# ----------------------------
# Processing Record | tura
# ----------------------------
# Processing Record | fare
# ----------------------------
# Processing Record | kaitangata
# ----------------------------
# Processing Record | westport
# ----------------------------
# Processing Record | ribeira grande
# ----------------------------
# Processing Record | pocatello
# ----------------------------
# Processing Record | gigmoto
# ----------------------------
# Processing Record | pisco
# ----------------------------
# Processing Record | guozhen
# ----------------------------
# Processing Record | janakpur
# ----------------------------
# Processing Record | coquimbo
# ----------------------------
# Processing Record | mar del plata
# ----------------------------
# Processing Record | khilok
# ----------------------------
# Processing Record | panacan
# ----------------------------
# Processing Record | kabanjahe
# ----------------------------
# Processing Record | arrifes
# ----------------------------
# Processing Record | kondinskoye
# ----------------------------
# Processing Record | asfi
# City not found. Skipping...
# ----------------------------
# Processing Record | takoradi
# ----------------------------
# Processing Record | louisbourg
# City not found. Skipping...
# ----------------------------
# Processing Record | zermatt
# ----------------------------
# Processing Record | williams lake
# ----------------------------
# Processing Record | chuy
# ----------------------------
# Processing Record | mahebourg
# ----------------------------
# Processing Record | narsaq
# ----------------------------
# Processing Record | margate
# ----------------------------
# Processing Record | oussouye
# ----------------------------
# Processing Record | rawson
# ----------------------------
# Processing Record | madoc
# ----------------------------
# Processing Record | araguacu
# City not found. Skipping...
# ----------------------------
# Processing Record | kisangani
# ----------------------------
# Processing Record | port lincoln
# ----------------------------
# Processing Record | shieli
# ----------------------------
# Processing Record | cheuskiny
# City not found. Skipping...
# ----------------------------
# Processing Record | krasnoselkup
# City not found. Skipping...
# ----------------------------
# Processing Record | regina
# ----------------------------
# Processing Record | yei
# City not found. Skipping...
# ----------------------------
# Processing Record | meulaboh
# ----------------------------
# Processing Record | tiksi
# ----------------------------
# Processing Record | nanortalik
# ----------------------------
# Processing Record | los llanos de aridane
# ----------------------------
# Processing Record | mollendo
# ----------------------------
# Processing Record | shizunai
# ----------------------------
# Processing Record | te anau
# ----------------------------
# Processing Record | uarini
# ----------------------------
# Processing Record | palm springs
# ----------------------------
# Processing Record | monrovia
# ----------------------------
# Processing Record | wuning
# ----------------------------
# Processing Record | turochak
# ----------------------------
# Processing Record | bandarbeyla
# ----------------------------
# Processing Record | zhangjiakou
# ----------------------------
# Processing Record | port-gentil
# ----------------------------
# Processing Record | isangel
# ----------------------------
# Processing Record | sompeta
# ----------------------------
# Processing Record | rafai
# ----------------------------
# Processing Record | dhone
# ----------------------------
# Processing Record | tigil
# ----------------------------
# Processing Record | chapleau
# ----------------------------
# Processing Record | jatai
# ----------------------------
# Processing Record | east london
# ----------------------------
# Processing Record | kulachi
# ----------------------------
# Processing Record | damietta
# ----------------------------
# Processing Record | bulaevo
# ----------------------------
# Processing Record | pevek
# ----------------------------
# Processing Record | pringsewu
# ----------------------------
# Processing Record | virginia beach
# ----------------------------
# Processing Record | asau
# City not found. Skipping...
# ----------------------------
# Processing Record | lalomanu
# City not found. Skipping...
# ----------------------------
# Processing Record | salcininkai
# ----------------------------
# Processing Record | trebisov
# ----------------------------
# Processing Record | comodoro rivadavia
# ----------------------------
# Processing Record | bollnas
# ----------------------------
# Processing Record | saint-philippe
# ----------------------------
# Processing Record | terra santa
# ----------------------------
# Processing Record | waddan
# ----------------------------
# Processing Record | ngukurr
# City not found. Skipping...
# ----------------------------
# Processing Record | giyani
# ----------------------------
# Processing Record | aljezur
# ----------------------------
# Processing Record | victor harbor
# ----------------------------
# Processing Record | lagoa
# ----------------------------
# Processing Record | bubaque
# ----------------------------
# Processing Record | bambous virieux
# ----------------------------
# Processing Record | helong
# ----------------------------
# Processing Record | kijang
# ----------------------------
# Processing Record | college
# ----------------------------
# Processing Record | muyezerskiy
# ----------------------------
# Processing Record | markova
# ----------------------------
# Processing Record | bauta
# ----------------------------
# Processing Record | tawnat
# City not found. Skipping...
# ----------------------------
# Processing Record | keighley
# ----------------------------
# Processing Record | hami
# ----------------------------
# Processing Record | kumba
# ----------------------------
# Processing Record | aitape
# ----------------------------
# Processing Record | port hedland
# ----------------------------
# Processing Record | kupang
# ----------------------------
# Processing Record | oxchuc
# ----------------------------
# Processing Record | zaton
# ----------------------------
# Processing Record | nuqui
# ----------------------------
# Processing Record | banda aceh
# ----------------------------
# Processing Record | saleaula
# City not found. Skipping...
# ----------------------------
# Processing Record | villazon
# City not found. Skipping...
# ----------------------------
# Processing Record | pandan
# ----------------------------
# Processing Record | sitka
# ----------------------------
# Processing Record | colares
# ----------------------------
# Processing Record | goderich
# ----------------------------
# Processing Record | doha
# ----------------------------
# Processing Record | tilichiki
# ----------------------------
# Processing Record | korla
# City not found. Skipping...
# ----------------------------
# Processing Record | helena
# ----------------------------
# Processing Record | oliveira dos brejinhos
# ----------------------------
# Processing Record | sur
# ----------------------------
# Processing Record | leningradskiy
# ----------------------------
# Processing Record | never
# ----------------------------
# Processing Record | belawan
# ----------------------------
# Processing Record | saldanha
# ----------------------------
# Processing Record | byron bay
# ----------------------------
# Processing Record | lebanon
# ----------------------------
# Processing Record | dzhusaly
# City not found. Skipping...
# ----------------------------
# Processing Record | anshun
# ----------------------------
# Processing Record | codrington
# ----------------------------
# Processing Record | aviles
# ----------------------------
# Processing Record | cabedelo
# ----------------------------
# Processing Record | shchelyayur
# City not found. Skipping...
# ----------------------------
# Processing Record | cap malheureux
# ----------------------------
# Processing Record | sanislau
# ----------------------------
# Processing Record | camana
# City not found. Skipping...
# ----------------------------
# Processing Record | auki
# ----------------------------
# Processing Record | payo
# ----------------------------
# Processing Record | sorland
# ----------------------------
# Processing Record | innisfail
# ----------------------------
# Processing Record | salta
# ----------------------------
# Processing Record | meadow lake
# ----------------------------
# Processing Record | kushima
# ----------------------------
# Processing Record | roebourne
# ----------------------------
# Processing Record | sopot
# ----------------------------
# Processing Record | bichura
# ----------------------------
# Processing Record | sabang
# ----------------------------
# Processing Record | broken hill
# ----------------------------
# Processing Record | bonavista
# ----------------------------
# Processing Record | fenoarivo
# ----------------------------
# Processing Record | lima
# ----------------------------
# Processing Record | iqaluit
# ----------------------------
# Processing Record | deh rawud
# City not found. Skipping...
# ----------------------------
# Processing Record | popondetta
# ----------------------------
# Processing Record | ilhabela
# ----------------------------
# Processing Record | mount gambier
# ----------------------------
# Processing Record | dicabisagan
# ----------------------------
# Processing Record | xichang
# ----------------------------
# Processing Record | abilay
# ----------------------------
# Processing Record | codajas
# ----------------------------
# Processing Record | ostrovnoy
# ----------------------------
# Processing Record | chala
# ----------------------------
# Processing Record | singkang
# ----------------------------
# Processing Record | aksu
# ----------------------------
# Processing Record | sohbatpur
# ----------------------------
# Processing Record | la primavera
# ----------------------------
# Processing Record | khasan
# ----------------------------
# Processing Record | beidao
# ----------------------------
# Processing Record | udachnyy
# ----------------------------
# Processing Record | george town
# ----------------------------
# Processing Record | kobojango
# City not found. Skipping...
# ----------------------------
# Processing Record | san
# ----------------------------
# Processing Record | chisindia
# ----------------------------
# Processing Record | sechura
# ----------------------------
# Processing Record | la asuncion
# ----------------------------
# Processing Record | sao filipe
# ----------------------------
# Processing Record | sorvag
# City not found. Skipping...
# ----------------------------
# Processing Record | usinsk
# ----------------------------
# Processing Record | iisalmi
# ----------------------------
# Processing Record | talnakh
# ----------------------------
# Processing Record | drayton valley
# ----------------------------
# Processing Record | san mateo del mar
# ----------------------------
# Processing Record | batagay
# ----------------------------
# Processing Record | mandalgovi
# ----------------------------
# Processing Record | mahibadhoo
# ----------------------------
# Processing Record | tomatlan
# ----------------------------
# Processing Record | siguiri
# ----------------------------
# Processing Record | vardo
# ----------------------------
# Processing Record | sao joao da barra
# ----------------------------
# Processing Record | plettenberg bay
# ----------------------------
# Processing Record | murray bridge
# ----------------------------
# Processing Record | yumen
# ----------------------------
# Processing Record | pacifica
# ----------------------------
# Processing Record | kulhudhuffushi
# ----------------------------
# Processing Record | tungor
# ----------------------------
# Processing Record | araouane
# ----------------------------
# Processing Record | mozarlandia
# ----------------------------
# Processing Record | topolobampo
# ----------------------------
# Processing Record | concarneau
# ----------------------------
# Processing Record | anadyr
# ----------------------------
# Processing Record | aklavik
# ----------------------------
# Processing Record | soto la marina
# ----------------------------
# Processing Record | pasighat
# ----------------------------
# Processing Record | luis correia
# ----------------------------
# Processing Record | clearwater
# ----------------------------
# Processing Record | de aar
# ----------------------------
# Processing Record | zolotinka
# City not found. Skipping...
# ----------------------------
# Processing Record | buraydah
# ----------------------------
# Processing Record | simao
# ----------------------------
# Processing Record | huazolotitlan
# City not found. Skipping...
# ----------------------------
# Processing Record | loiza
# ----------------------------
# Processing Record | necochea
# ----------------------------
# Processing Record | sentyabrskiy
# City not found. Skipping...
# ----------------------------
# Processing Record | cubara
# ----------------------------
# Processing Record | ust-kut
# ----------------------------
# Processing Record | vila franca do campo
# ----------------------------
# Processing Record | tasbuget
# City not found. Skipping...
# ----------------------------
# Processing Record | north branch
# ----------------------------
# Processing Record | kungurtug
# ----------------------------
# Processing Record | yerbogachen
# ----------------------------
# Processing Record | timmins
# ----------------------------
# Processing Record | maniitsoq
# ----------------------------
# Processing Record | aksarayskiy
# ----------------------------
# Processing Record | vaitupu
# City not found. Skipping...
# ----------------------------
# Processing Record | agnibilekrou
# ----------------------------
# Processing Record | mega
# ----------------------------
# Processing Record | caravelas
# ----------------------------
# Processing Record | houston
# ----------------------------
# Processing Record | ixtapa
# ----------------------------
# Processing Record | tubruq
# City not found. Skipping...
# ----------------------------
# Processing Record | havre-saint-pierre
# ----------------------------
# Processing Record | cap-aux-meules
# ----------------------------
# Processing Record | mainit
# ----------------------------
# Processing Record | araguatins
# City not found. Skipping...
# ----------------------------
# Processing Record | fuerte olimpo
# ----------------------------
# Processing Record | rozkishne
# ----------------------------
# Processing Record | gazimagusa
# City not found. Skipping...
# ----------------------------
# Processing Record | breytovo
# ----------------------------
# Processing Record | beni
# ----------------------------
# Processing Record | murdochville
# ----------------------------
# Processing Record | washougal
# ----------------------------
# Processing Record | kuremaa
# ----------------------------
# Processing Record | moose factory
# ----------------------------
# Processing Record | olafsvik
# City not found. Skipping...
# ----------------------------
# Processing Record | umm lajj
# ----------------------------
# Processing Record | flinders
# ----------------------------
# Processing Record | ekhabi
# ----------------------------
# Processing Record | daru
# ----------------------------
# Processing Record | tekirdag
# ----------------------------
# Processing Record | kattivakkam
# ----------------------------
# Processing Record | san cristobal
# ----------------------------
# Processing Record | seoul
# ----------------------------
# Processing Record | geraldton
# ----------------------------
# Processing Record | aleksandrov gay
# ----------------------------
# Processing Record | bushenyi
# ----------------------------
# Processing Record | calvinia
# ----------------------------
# Processing Record | santo antonio do sudoeste
# ----------------------------
# Processing Record | poum
# ----------------------------
# Processing Record | yuanping
# ----------------------------
# Processing Record | tornio
# ----------------------------
# Processing Record | alice springs
# ----------------------------
# Processing Record | provideniya
# ----------------------------
# Processing Record | karaton
# ----------------------------
# Processing Record | sampit
# ----------------------------
# Processing Record | ahipara
# ----------------------------
# Processing Record | pochutla
# ----------------------------
# Processing Record | muscat
# ----------------------------
# Processing Record | diffa
# ----------------------------
# Processing Record | satitoa
# City not found. Skipping...
# ----------------------------
# Processing Record | ushirombo
# ----------------------------
# Processing Record | osypenko
# ----------------------------
# Processing Record | deputatskiy
# ----------------------------
# Processing Record | rio cuarto
# ----------------------------
# Processing Record | genhe
# ----------------------------
# Processing Record | saint-augustin
# ----------------------------
# Processing Record | christchurch
# ----------------------------
# Processing Record | el faiyum
# City not found. Skipping...
# ----------------------------
# Processing Record | kayerkan
# ----------------------------
# Processing Record | kashi
# City not found. Skipping...
# ----------------------------
# Processing Record | along
# ----------------------------
# Processing Record | cherskiy
# ----------------------------
# Processing Record | nemuro
# ----------------------------
# Processing Record | marsassoum
# ----------------------------
# Processing Record | vredendal
# ----------------------------
# Processing Record | omboue
# ----------------------------
# Processing Record | romny
# ----------------------------
# Processing Record | gobo
# ----------------------------
# Processing Record | lososina
# ----------------------------
# Processing Record | point fortin
# ----------------------------
# Processing Record | kailua
# ----------------------------
# Processing Record | cockburn town
# ----------------------------
# Processing Record | viligili
# City not found. Skipping...
# ----------------------------
# Processing Record | guiyang
# ----------------------------
# Processing Record | saint-francois
# ----------------------------
# Processing Record | gao
# ----------------------------
# Processing Record | kyshtovka
# ----------------------------
# Processing Record | port hardy
# ----------------------------
# Processing Record | warqla
# City not found. Skipping...
# ----------------------------
# Processing Record | aflu
# City not found. Skipping...
# ----------------------------
# Processing Record | burnie
# ----------------------------
# Processing Record | coos bay
# ----------------------------
# Processing Record | rondonopolis
# ----------------------------
# Processing Record | klaksvik
# ----------------------------
# Processing Record | ishigaki
# ----------------------------
# Processing Record | riyadh
# ----------------------------
# Processing Record | ambilobe
# ----------------------------
# Processing Record | anahuac
# ----------------------------
# Processing Record | mogadishu
# ----------------------------
# Processing Record | portland
# ----------------------------
# Processing Record | prince rupert
# ----------------------------
# Processing Record | umzimvubu
# City not found. Skipping...
# ----------------------------
# Processing Record | chumikan
# ----------------------------
# Processing Record | verkhnyaya sinyachikha
# ----------------------------
# Processing Record | harper
# ----------------------------
# Processing Record | kinloss
# ----------------------------
# Processing Record | faya
# ----------------------------
# Processing Record | hasaki
# ----------------------------
# Processing Record | russell
# ----------------------------
# Processing Record | ozernovskiy
# ----------------------------
# Processing Record | kaseda
# ----------------------------
# Processing Record | huilong
# ----------------------------
# Processing Record | timra
# ----------------------------
# Processing Record | tefe
# ----------------------------
# Processing Record | san policarpo
# ----------------------------
# Processing Record | athabasca
# ----------------------------
# Processing Record | grand river south east
# City not found. Skipping...
# ----------------------------
# Processing Record | san jose
# ----------------------------
# Processing Record | paradwip
# City not found. Skipping...
# ----------------------------
# Processing Record | gornopravdinsk
# ----------------------------
# Processing Record | catamarca
# City not found. Skipping...
# ----------------------------
# Processing Record | vao
# ----------------------------
# Processing Record | micomeseng
# ----------------------------
# Processing Record | chaoyang
# ----------------------------
# Processing Record | kaya
# ----------------------------
# Processing Record | dingle
# ----------------------------
# Processing Record | chicama
# ----------------------------
# Processing Record | marcona
# City not found. Skipping...
# ----------------------------
# Processing Record | dovers
# ----------------------------
# Processing Record | manaus
# ----------------------------
# Processing Record | clinton
# ----------------------------
# Processing Record | dhanera
# ----------------------------
# Processing Record | basco
# ----------------------------
# Processing Record | srednekolymsk
# ----------------------------
# Processing Record | noumea
# ----------------------------
# Processing Record | zhuhai
# ----------------------------
# Processing Record | teya
# ----------------------------
# Processing Record | cortez
# ----------------------------
# Processing Record | matagami
# ----------------------------
# Processing Record | jaru
# ----------------------------
# Processing Record | funadhoo
# ----------------------------
# Processing Record | jaisalmer
# ----------------------------
# Processing Record | panorama
# ----------------------------
# Processing Record | preobrazheniye
# ----------------------------
# Processing Record | constitucion
# ----------------------------
# Processing Record | moroni
# ----------------------------
# Processing Record | mrirt
# City not found. Skipping...
# ----------------------------
# Processing Record | seryshevo
# ----------------------------
# Processing Record | iracoubo
# ----------------------------
# Processing Record | morant bay
# ----------------------------
# Processing Record | nchelenge
# ----------------------------
# Processing Record | vuktyl
# ----------------------------
# Processing Record | san angelo
# ----------------------------
# Processing Record | la ronge
# ----------------------------
# Processing Record | ruatoria
# City not found. Skipping...
# ----------------------------
# Processing Record | broome
# ----------------------------
# Processing Record | puerto quijarro
# ----------------------------
# Processing Record | deogarh
# ----------------------------
# Processing Record | high level
# ----------------------------
# Processing Record | cabra
# ----------------------------
# Processing Record | cascais
# ----------------------------
# Processing Record | jackson
# ----------------------------
# Processing Record | partyzany
# ----------------------------
# Processing Record | ghatal
# ----------------------------
# Processing Record | balykshi
# City not found. Skipping...
# ----------------------------
# Processing Record | conakry
# ----------------------------
# Processing Record | lyngseidet
# ----------------------------
# Processing Record | brownsville
# ----------------------------
# Processing Record | baglan
# ----------------------------
# Processing Record | ribeira brava
# ----------------------------
# Processing Record | finschhafen
# ----------------------------
# Processing Record | mizpe ramon
# City not found. Skipping...
# ----------------------------
# Processing Record | cagayan de tawi-tawi
# City not found. Skipping...
# ----------------------------
# Processing Record | little current
# ----------------------------
# Processing Record | eydhafushi
# ----------------------------
# Processing Record | nueve de julio
# ----------------------------
# Processing Record | brownwood
# ----------------------------
# Processing Record | kualakapuas
# ----------------------------
# Processing Record | srivardhan
# ----------------------------
# Processing Record | yorosso
# ----------------------------
# Processing Record | conceicao do araguaia
# ----------------------------
# Processing Record | tonekabon
# ----------------------------
# Processing Record | karsava
# ----------------------------
# Processing Record | coihaique
# ----------------------------
# Processing Record | breyten
# ----------------------------
# Processing Record | wajir
# ----------------------------
# Processing Record | aksarka
# ----------------------------
# Processing Record | vanavara
# ----------------------------
# Processing Record | kazalinsk
# City not found. Skipping...
# ----------------------------
# Processing Record | namwala
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": Cities,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity, 
    "Lat": lat, 
    "Lng": lng, 
    "Max Temp": max_temp, 
    "Wind Speed": wind_speed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Katsuura          75      JP  1563876602        94  33.93  134.50
# 1          Bima           2      ID  1563876145        39  -8.45  118.73
# 2     Moctezuma          91      MX  1563848282        71  29.81 -109.68
# 3  Puerto Ayora          62      EC  1563840607        92  -0.74  -90.35
# 4          Lebu          75      ET  1563896894        87   8.96   38.73
#
#    Max Temp  Wind Speed
# 0     82.40        9.17
# 1     84.46        7.63
# 2     74.20        5.88
# 3     68.00        3.00
# 4     55.40        6.93

# %%
weather_data.count()
# Out:
# City          525
# Cloudiness    525
# Country       525
# Date          525
# Humidity      525
# Lat           525
# Lng           525
# Max Temp      525
# Wind Speed    525
# dtype: int64

# %%
weather_data["Date"] = pd.to_datetime(weather_data["Date"])

# %%
weather_data.to_csv("Weather_Data_isoto.csv") 

weather_data.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.rc('grid', linestyle = "-", color = "gray")
lat_temp = plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker = "o", facecolors = "b", 
                       edgecolors = "black", alpha = 0.75)
plt.grid(True)
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("Lat_vs_Temp")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.rc('grid', linestyle = "-", color = "gray")
lat_humid = plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker = "o", facecolors = "b", 
                       edgecolors = "black", alpha = 0.75)
plt.grid(True)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.savefig("Lat_vs_Humid")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.rc('grid', linestyle = "-", color = "gray")
lat_cloudy = plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker = "o", facecolors = "b", 
                       edgecolors = "black", alpha = 0.75)
plt.grid(True)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("Lat_vs_Cloud")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.rc('grid', linestyle = "-", color = "gray")
lat_wind = plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker = "o", facecolors = "b", 
                       edgecolors = "black", alpha = 0.75)
plt.grid(True)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("Lat_vs_WindSpeed")
